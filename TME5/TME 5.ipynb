# %% [markdown]
# # TME 5 TAL

# %%
import numpy as  np
import codecs
import matplotlib.pyplot as plt
import unicodedata
import re
from collections import Counter,defaultdict
import nltk.corpus.reader as pt
import os

import string
import pdb
import nltk
import scipy

# %% [markdown]
# ## 1. Chargement des données (automatique)

# %%
import nltk.corpus.reader as pt
path2data = u'20news-bydate-train/'

rdr = pt.CategorizedPlaintextCorpusReader(path2data, '.*/[0-9]+', encoding='latin1', cat_pattern='([\w\.]+)/*')
docs = [[rdr.raw(fileids=[f]) for f in rdr.fileids(c) ] for c in rdr.categories()]

# %% [markdown]
# ## 2. Chargement des données (à la main)

# %%
def readAFile(nf):
    f = open(nf, 'rb')

    txt = f.readlines()
    txt = ' '.join(txt)

    f.close()
    return txt

def compteLignes(nf, fdl='\n', tbuf=16384):
    """Compte le nombre de lignes du fichier nf"""
    c = 0
    f = open(nf, 'rb')
    while True:
        buf = None
        buf = f.read(tbuf)
        if len(buf)==0:
            break
        c += buf.count(fdl)
    f.seek(-1, 2)
    car = f.read(1)
    if car != fdl:
        c += 1
    f.close()
    return c

# %% [markdown]
# ## sac de mots

# %%
def preprocessSent(s):
    punc = u''.join([ch for ch in string.punctuation]) # je laisse les points pour pouvoir séparer les phrases
    punc += u'\n\r\t\\'
    table =string.maketrans(punc + string.digits, ' '*(len(punc)+len(string.digits)))
    s = string.translate(unicodedata.normalize("NFKD",s).encode("ascii","ignore"),table).lower() # elimination des accents + minuscules
    return s
def count_ngrams(s,n=2,dic=None):
    if dic is None:
        dic=Counter()
    for i in range(len(s)):
        for j in range(i+1,min(i+n+1,len(s)+1)):
            dic[u''.join(s[i:j])]+=1
    return dic

# %%
docProPre = [[] for i in range(len(docs))]
for i in range(len(docs)):
    for j in range(len(docs[i])):
        docProPre[i].append(preprocessSent(docs[i][j]))
    docProPre[i]=[s[:-1] for s in docProPre[i] if len(s)>2] # elimination des phrases/docs vides

# %%
from pympler import asizeof
asizeof.asizeof(docProPre)
# Out:
# 20886592

# %%
from nltk.corpus import stopwords

for i in range(len(docs)):
    print i,"/",len(docs)
    for j in range(len(docs[i])):
        docProPre[i][j] = ' '.join([word for word in docProPre[i][j].split() if word not in (stopwords.words('english'))])
#preprocesing supplémentaire facultatif
# Out:
# 0 / 20
# 1 / 20
# 2 / 20
# 3 / 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-5d6369b64adb> in <module>()
#       4     print i,"/",len(docs)
#       5     for j in range(len(docs[i])):
# ----> 6         docProPre[i][j] = ' '.join([word for word in docProPre[i][j].split() if word not in (stopwords.words('english'))])
#
# /home/melki/anaconda2/lib/python2.7/site-packages/nltk/corpus/reader/wordlist.pyc in words(self, fileids)
#      18     """
#      19     def words(self, fileids=None):
# ---> 20         return line_tokenize(self.raw(fileids))
#      21
#      22     def raw(self, fileids=None):
#
# /home/melki/anaconda2/lib/python2.7/site-packages/nltk/corpus/reader/wordlist.pyc in raw(self, fileids)
#      23         if fileids is None: fileids = self._fileids
#      24         elif isinstance(fileids, compat.string_types): fileids = [fileids]
# ---> 25         return concat([self.open(f).read() for f in fileids])
#      26
#      27
#
# /home/melki/anaconda2/lib/python2.7/site-packages/nltk/corpus/reader/api.pyc in open(self, file)
#     208         """
#     209         encoding = self.encoding(file)
# --> 210         stream = self._root.join(file).open(encoding)
#     211         return stream
#     212
#
# /home/melki/anaconda2/lib/python2.7/site-packages/nltk/data.pyc in join(self, fileid)
#     320     def join(self, fileid):
#     321         _path = os.path.join(self._path, fileid)
# --> 322         return FileSystemPathPointer(_path)
#     323
#     324     def __repr__(self):
#
# /home/melki/anaconda2/lib/python2.7/site-packages/nltk/compat.pyc in _decorator(*args, **kwargs)
#     562     def _decorator(*args, **kwargs):
#     563         args = (args[0], add_py3_data(args[1])) + args[2:]
# --> 564         return init_func(*args, **kwargs)
#     565     return wraps(init_func)(_decorator)
#     566
#
# /home/melki/anaconda2/lib/python2.7/site-packages/nltk/data.pyc in __init__(self, _path)
#     296         """
#     297
# --> 298         _path = os.path.abspath(_path)
#     299         if not os.path.exists(_path):
#     300             raise IOError('No such file or directory: %r' % _path)
#
# /home/melki/anaconda2/lib/python2.7/posixpath.pyc in abspath(path)
#     364             cwd = os.getcwd()
#     365         path = join(cwd, path)
# --> 366     return normpath(path)
#     367
#     368
#
# /home/melki/anaconda2/lib/python2.7/posixpath.pyc in normpath(path)
#     339         path.startswith('//') and not path.startswith('///')):
#     340         initial_slashes = 2
# --> 341     comps = path.split('/')
#     342     new_comps = []
#     343     for comp in comps:
#
# KeyboardInterrupt:

# %%
from pympler import asizeof
asizeof.asizeof(docProPre)
# Out:
# 20886592

# %%
indToDic = {}
dicToInd = {}
v = np.unique(np.array([a for doc in docProPre for w in doc for a in w.split()]))
for i,w in enumerate(v):
    
    dicToInd[i]=w
    indToDic[w]=i

# %%
D = len(dicToInd)
docP = [docProPre[i][j].split() for i in range(len(docProPre)) for j in range(len(docProPre[i]))  ]
N=len(docP)

# %%
bow=scipy.sparse.lil_matrix((N,D))
cpt=0
def add1(i,j):
    bow[i,j] += 1

# %%
[[add1(i,indToDic[m]) for m in s if m in indToDic] for i,s in enumerate(docP)]

print "bow computed"
# Out:
# bow computed

# %%
print asizeof.asizeof(bow)
sumBow = bow.sum(1)
# Out:
# 182896

# %%
bowN = bow / sumBow

#je n'arrive plus à faire cette opération qui marchait bien avant, peut être une perte de RAM..
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-7ef28717cd0d> in <module>()
# ----> 1 bowN = bow / sumBow
#       2
#       3 #je n'arrive plus à faire cette opération qui marchait bien avant, peut être une perte de RAM..
#
# /home/melki/anaconda2/lib/python2.7/site-packages/scipy/sparse/base.pyc in __div__(self, other)
#     456     def __div__(self, other):
#     457         # Always do true division
# --> 458         return self._divide(other, true_divide=True)
#     459
#     460     def __rtruediv__(self, other):
#
# /home/melki/anaconda2/lib/python2.7/site-packages/scipy/sparse/base.pyc in _divide(self, other, true_divide, rdivide)
#     431             if not rdivide:
#     432                 if true_divide:
# --> 433                     return np.true_divide(self.todense(), other)
#     434                 else:
#     435                     return np.divide(self.todense(), other)
#
# MemoryError:

# %%
import numpy.random as rand
prototypes = bowN[rand.permutation(N)[:20]]
#on fait les permutations avant de se lancer dans le kmeans, 20 classes.

# %%
sim = bowN.dot(prototypes.T) 
y= sim.argmax(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-be2fdc8f2730> in <module>()
# ----> 1 sim = bowN.dot(prototypes.T)
#       2 y= sim.argmax(1)
#
# NameError: name 'bowN' is not defined

# %%
for ite in range(20):
    sim = bowN.dot(prototypes.T) # métrique type cos
    
    
    y= sim.argmax(1) # comprendre les dimensions des matrices pour comprendre ce calcul
    
    for i in np.unique(np.array(y)):
        
        prototypes[i] = bowN[np.where(y==i)[0]].sum(axis=1)/np.array(np.where(y==i)).shape[2]
    print 'itérations '+str(ite) +" check"
    
#on itère 20 fois (c'était un calcul long, c'était une heure pour 20 itérations, on peux bien entendu faire beaucoup plus)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-84bfa4fb2d57> in <module>()
#       3
#       4
# ----> 5     y= sim.argmax(1) # comprendre les dimensions des matrices pour comprendre ce calcul
#       6
#       7     for i in np.unique(np.array(y)):
#
# /home/melki/anaconda2/lib/python2.7/site-packages/scipy/sparse/base.pyc in __getattr__(self, attr)
#     523             return self.getnnz()
#     524         else:
# --> 525             raise AttributeError(attr + " not found")
#     526
#     527     def transpose(self):
#
# AttributeError: argmax not found

# %%
ySur = [i for i,doc in enumerate(docs) for di in doc]

# %%
nb_classes=20
purete = np.zeros((20,2))

for c in range(nb_classes):
    index=np.where(y==c)[0]
    #print ySur[index]
    count=np.bincount(ySur[index][0])
    m=np.max(count)*100./np.array(np.where(y==c)).shape[2]
    
    
    
    
    purete[c] = np.argmax(count),m
   
    
print purete


#on calcule la pureté de chaque ensemble, à gauche la classe majoritaire et à droite le pourcentage de présence.
# Out:
# [[  9.          42.22222222]
#  [  0.          15.82278481]
#  [ 10.          90.47619048]
#  [  6.          66.66666667]
#  [  9.          12.92517007]
#  [  6.          51.18110236]
#  [  5.          29.06976744]
#  [  5.          34.48275862]
#  [  1.          14.28571429]
#  [ 12.          12.05479452]
#  [  9.          15.29680365]
#  [  8.          20.        ]
#  [  1.          16.52173913]
#  [ 10.          16.        ]
#  [ 11.           6.89655172]
#  [ 12.          12.25806452]
#  [  6.          50.        ]
#  [  2.          12.68715524]
#  [  5.          24.        ]
#  [  7.          10.6918239 ]]
